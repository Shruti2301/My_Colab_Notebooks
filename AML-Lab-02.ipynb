# %%
rawstr = input('Enter a number: ')

try:
  ival = int(rawstr)
except:
  ival = -1

if ival > 0:
  print('Nice work')
else:
  print('Not a number')
# Out:
# Enter a number: -3
# Not a number

# %%
hrs = int(input('Enter hours: '))
rate = int(input('Enter rate: '))
print('Gross pay = ',hrs*rate)
# Out:
# Enter hours: 95
# Enter rate: 2
# Gross pay =  190

# %%
def add(x,y,z=None):
  if (z==None):
    return x+y
  else:
    return x+y+z

# %%
print(add(30,3))
# Out:
# 33

# %%
class Person:
  institute = 'MSIS' #a class variable

  #self keyword to access the attributes and methods of the class
  def set_name(self, new_name):
    self.name = new_name
  def set_location(self, new_location):
    self.location = new_location

# %%
x = 1

if x < 2:
  print('Below 2')
elif x>=2:
  print('Two or more')
else:
  print('Something else')
# Out:
# Below 2

# %% [markdown]
# Something else won't print ever

# %%
x = 21

if x < 2:
  print('Below 2')
elif x < 20:
  print('Below 20')
elif x < 10:
  print('Below 10')
else:
  print('Something else')
# Out:
# Something else

# %% [markdown]
# Below 10 won't print

# %%
hrs = int(input('Enter hours: '))
rate = int(input('Enter rate: '))

try:
  print('Gross pay = ',hrs*rate)
except:
  print('Input not correct')
# Out:
# Enter hours: 30
# Enter rate: i
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-39384f2d09bb> in <module>()
#       1 hrs = int(input('Enter hours: '))
# ----> 2 rate = int(input('Enter rate: '))
#       3
#       4 try:
#       5   print('Gross pay = ',hrs*rate)
#
# ValueError: invalid literal for int() with base 10: 'i'

# %%
n = 0
while n>0:
  print('Lather')
  print('Rinse')
print('Dry off!')
# Out:
# Dry off!

# %% [markdown]
# Infinite Loop for n = 5<br>
# 'Dry off!' for n=0

# %%
lst = [9, 41, 23, 54, 33, 21, 8]

# %%
def paycomp(hours, rate):
  if hours > 40:
    # anything over 40 hours earns the overtime rate
    overtimeRate = 1.5 * rate
    overtime = (hours-40) * overtimeRate
    # the remaining 40 hours will earn the regular rate
    hours = 40
  else:
    # if you didn't work over 40 hours, there is no overtime
    overtime = 0
  print('Gross pay = ',(hours*rate)+overtime)

hrs = int(input('Enter hours: '))
rate = int(input('Enter rate: '))
paycomp(hrs,rate)
# Out:
# Enter hours: 45
# Enter rate: 10
# 475.0

# %%
nums = [9, 41, 23, 54, 33, 21, 8]
max_value = -1
min_value = 9999999
count = 0
count_odd = 0
count_even = 0
count_prime = 0
sum = 0
avg = 0
for n in nums: # find max
    if n > max_value: max_value = n
for n in nums: # find min
    if n < min_value: min_value = n
for n in nums: # count
    count = count + 1
for n in nums: # count odd numbers
    if n % 2 != 0: count_odd = count_odd + 1
for n in nums: # count even numbers
    if n % 2 == 0: count_even = count_even + 1
for n in nums: # find prime numbers
  if(n<2):
    continue
  else:
    for i in range(2,n):
      if(n%i==0):
          break
    else:
      count_prime+=1
for n in nums: # sum of numbers
    sum += n
avg = sum/len(nums) # average of numbers

greater_than_20 = [n for n in nums if n > 20] # greater tha 20
less_than_15 = [n for n in nums if n < 15] # less than 15
for n in nums: # search number 3
    if n == 3: print('Number found')
print('Number not found')
# Out:
# Number not found

# %%
prime_numbers = [2, 3, 5, 7]
print(type(prime_numbers))
numbers_dict = {1: 'one', 2: 'two'}
print(type(numbers_dict))
# Out:
# <class 'list'>
# <class 'dict'>
